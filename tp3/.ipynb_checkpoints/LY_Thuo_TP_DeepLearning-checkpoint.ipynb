# %% [markdown]
# # 📝 Pattern Recognition & Biometrics. TP Apprentissage profond ou *Deep Learning*
#
# Par Omar Galarraga et Sonia Garcia

# %% [markdown]
# Dans ce travail pratique, nous verrons l'intérêt des modèles d'apprentissage profond (*Deep Learning*) en les comparant à des modèles de *Machine Learning* classiques (non profonds).
#
# Nous voudrons identifier les animaux et les objets à partir des images de la base de données CIFAR 10 (https://www.cs.toronto.edu/%7Ekriz/cifar.html).
#
# Commençons par charger les données...

# %%
import tensorflow as tf

from tensorflow import keras
from keras import datasets
from keras.models import Sequential
from keras.layers import Dense, MaxPooling2D, Conv2D, Flatten

(data_train, target_train), (data_test, target_test) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# A manière d'exemple, nous afficherons 3 images de chaque classe :

# %%
import matplotlib.pyplot as plt
import numpy as np
classes = ['avion', 'voiture', 'oiseau', 'chat', 'cerf', 
            'chien', 'crapaud', 'cheval', 'bateau', 'camion']

# Normalisation des valeurs des pixels entre 0 and 1
data_train, data_test = data_train / 255.0, data_test / 255.0

n_images = 3

plt.figure(figsize=(10,10))
for i in range(len(classes)):
  idx = np.where(target_train == i)
  #print(idx)
  for j in range(n_images): 
    plt.subplot(len(classes),n_images,n_images*i+j+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(data_train[idx[0][j]])
    if j == 0:
        plt.ylabel(classes[target_train[idx[0][j]][0]])
plt.show()

# %% [markdown]
# ## Partie I. *Feedforward Neural Network* à une seule couche cachée
#
# Nous construisons un réseau de neurones avec $N_{H_l} = 1$ couche cachée et $m=32$ neurones dans la couche cachée.
#
# * I.1) Si on considère les images "brutes", quelle est la dimension de la "couche" d'entrée ?
#
#     ***Réponse:***
#     The dimention of the input layer is $32*32$ RGB which is $ 32*32*3 = 3072$
#
# * I.2) Quelle est la performance du modèle sur les ensembles d'apprentissage et de test ?

# %%
data_train[0].shape
# Out:
# (32, 32, 3)

# %%
m=32
refmodel = tf.keras.Sequential()
refmodel.add(Flatten(input_shape=data_train[0].shape)) #convert the multi-demensional neurol into the 1D vector 
refmodel.add(Dense(m, activation='sigmoid'))
refmodel.add(Dense(len(classes)))

refmodel.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history1 = refmodel.fit(data_train, target_train, epochs=20, 
                        validation_data=(data_test, target_test), batch_size=64)
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2595 - loss: 2.0543 - val_accuracy: 0.3594 - val_loss: 1.8274
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3654 - loss: 1.8008 - val_accuracy: 0.3736 - val_loss: 1.7654
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3859 - loss: 1.7328 - val_accuracy: 0.3849 - val_loss: 1.7219
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3994 - loss: 1.6978 - val_accuracy: 0.3977 - val_loss: 1.7047
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4115 - loss: 1.6636 - val_accuracy: 0.4056 - val_loss: 1.6756
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4221 - loss: 1.6315 - val_accuracy: 0.4153 - val_loss: 1.6528
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4240 - loss: 1.6225 - val_accuracy: 0.4267 - val_loss: 1.6159
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4362 - loss: 1.5961 - val_accuracy: 0.4300 - val_loss: 1.6118
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4354 - loss: 1.5951 - val_accuracy: 0.4221 - val_loss: 1.6256
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4465 - loss: 1.5667 - val_accuracy: 0.4232 - val_loss: 1.6140
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4450 - loss: 1.5644 - val_accuracy: 0.4283 - val_loss: 1.5915
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4517 - loss: 1.5483 - val_accuracy: 0.4303 - val_loss: 1.5938
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4537 - loss: 1.5371 - val_accuracy: 0.4243 - val_loss: 1.5951
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4570 - loss: 1.5293 - val_accuracy: 0.4255 - val_loss: 1.6083
# Epoch 15/20
# 767/782 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.4591 - loss: 1.5204

# %%
import matplotlib.pyplot as plt

plt.plot(fnns.history['accuracy'], label='Training Accuracy')
plt.plot(fnns.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

print("Final Training Accuracy: ", history1.history['accuracy'][-1])
print("Final Validation Accuracy: ", history1.history['val_accuracy'][-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 14>()
#       1 # import matplotlib.pyplot as plt
#       2
#       3 # plt.plot(fnns.history['accuracy'], label='Training Accuracy')
#    (...)
#      11 # print("Final Training Accuracy: ", history1.history['accuracy'][-1])
#      12 # print("Final Validation Accuracy: ", history1.history['val_accuracy'][-1])
# ---> 14 print('Training set accuracy:', fnns.evaluate(data_train, target_train)[1])
#      15 print('Testing set accuracy:', fnns.evaluate(data_test, target_test)[1])
#
# AttributeError: 'History' object has no attribute 'evaluate'

# %% [markdown]
# Optimisez le nombre de neurones dans la couche cachée dans l'intervalle $m = \left[2,128\right]$
# * I.3) Quelle est la valeur optimale de $ m $ ?
# * I.4) Quelles sont les nouvelles performances en apprentissage et en test ?

# %%
#Ecrivez votre code ici
acc_train = []
acc_test = []
m_list = list(range(2,129))
for m in m_list:
    
    refmodel = tf.keras.Sequential()
    refmodel.add(Flatten(input_shape=data_train[0].shape))
    refmodel.add(Dense(m, activation='sigmoid'))
    refmodel.add(Dense(len(classes)))

    refmodel.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    acc_train.append(refmodel.evaluate(data_train, target_train)[1])
    acc_test.append(refmodel.evaluate(data_test, target_test)[1])
    
    
print("Avec les performances de test:")
m_opt = m_list[acc_test.index(max(acc_test))]
print('- m_opt =', m_opt)
print('- La moyenne des performances de la validation croisée de m_opt =', max(acc_test))
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 463us/step - accuracy: 0.0994 - loss: 2.3775
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - accuracy: 0.0968 - loss: 2.3779
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 437us/step - accuracy: 0.0939 - loss: 2.3634
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - accuracy: 0.0941 - loss: 2.3617
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.0985 - loss: 2.3270
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - accuracy: 0.0985 - loss: 2.3283
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - accuracy: 0.1039 - loss: 2.3799
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - accuracy: 0.1025 - loss: 2.3836
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - accuracy: 0.0994 - loss: 2.3778
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.0968 - loss: 2.3820
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - accuracy: 0.1017 - loss: 2.4003
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - accuracy: 0.1036 - loss: 2.3992
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - accuracy: 0.1257 - loss: 2.4316
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - accuracy: 0.1221 - loss: 2.4327
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - accuracy: 0.1017 - loss: 2.4683
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - accuracy: 0.1007 - loss: 2.4680
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 437us/step - accuracy: 0.1009 - loss: 2.4165
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - accuracy: 0.0985 - loss: 2.4195
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 464us/step - accuracy: 0.1003 - loss: 2.3898
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - accuracy: 0.1027 - loss: 2.3884
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 462us/step - accuracy: 0.1018 - loss: 2.3996
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - accuracy: 0.1046 - loss: 2.4000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 460us/step - accuracy: 0.0928 - loss: 2.4575
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.0891 - loss: 2.4540
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 457us/step - accuracy: 0.0767 - loss: 2.3835
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.0763 - loss: 2.3844
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 462us/step - accuracy: 0.0999 - loss: 2.4627
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.0995 - loss: 2.4655
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 455us/step - accuracy: 0.0979 - loss: 2.3538
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - accuracy: 0.0947 - loss: 2.3576
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 488us/step - accuracy: 0.0999 - loss: 2.4710
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.0995 - loss: 2.4772
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 476us/step - accuracy: 0.0976 - loss: 2.3639
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 571us/step - accuracy: 0.0905 - loss: 2.4362
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.0937 - loss: 2.4374
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 645us/step - accuracy: 0.1017 - loss: 2.5520
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.1017 - loss: 2.5482
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - accuracy: 0.0954 - loss: 2.5737
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.0966 - loss: 2.5715
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step - accuracy: 0.1005 - loss: 2.6749
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - accuracy: 0.0987 - loss: 2.6789
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.1028 - loss: 2.4563
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - accuracy: 0.1003 - loss: 2.4568
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step - accuracy: 0.0968 - loss: 2.7064
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.0975 - loss: 2.7113
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - accuracy: 0.1003 - loss: 2.6052
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.1027 - loss: 2.6005
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 600us/step - accuracy: 0.1039 - loss: 2.4564
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.1070 - loss: 2.4567
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 574us/step - accuracy: 0.0982 - loss: 2.5086
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.0963 - loss: 2.5161
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 581us/step - accuracy: 0.1043 - loss: 2.4046
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.1059 - loss: 2.4000
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 639us/step - accuracy: 0.1384 - loss: 2.5198
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.1357 - loss: 2.5252
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 570us/step - accuracy: 0.1114 - loss: 2.3911
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.1073 - loss: 2.3928
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step - accuracy: 0.0968 - loss: 2.5353
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.0975 - loss: 2.5373
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 610us/step - accuracy: 0.0990 - loss: 2.4607
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.0985 - loss: 2.4582
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 609us/step - accuracy: 0.0994 - loss: 2.5039
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.0956 - loss: 2.5083
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 557us/step - accuracy: 0.1012 - loss: 2.5122
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.1023 - loss: 2.5081
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 574us/step - accuracy: 0.1020 - loss: 2.5563
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.1014 - loss: 2.5541
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 554us/step - accuracy: 0.1005 - loss: 2.5673
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.0988 - loss: 2.5718
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 552us/step - accuracy: 0.1347 - loss: 2.4257
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.1355 - loss: 2.4251
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 569us/step - accuracy: 0.0996 - loss: 2.5952
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.0988 - loss: 2.5965
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - accuracy: 0.1002 - loss: 2.8113
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.0984 - loss: 2.8074
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 581us/step - accuracy: 0.0736 - loss: 2.3769
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.0802 - loss: 2.3743
# Avec les performances de test:
# - m_opt = 125
# - La moyenne des performances de la validation croisée de m_opt = 0.13570000231266022

# %% [markdown]
# Montrez la matrice de confusion du modèle optimal sur l'ensemble de test
#
# * I.4) Quelle est la prédiction "préférée" du modèle ?
# * I.5) Quelle est la classe la mieux prédite ? Justifiez brièvement

# %%
#Ecrivez votre code ici
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assurez-vous que model est le modèle optimal obtenu précédemment
y_test_predictions = refmodel.predict(data_test)
predicted_classes = np.argmax(y_test_predictions, axis=1)

# Calcul de la matrice de confusion
cm = confusion_matrix(target_test, predicted_classes)
#print("Matrice de confusion :\n", cm)

# Visualisation de la matrice de confusion
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Analyse pour trouver la prédiction préférée et la classe la mieux prédite
most_predicted_class = np.argmax(np.sum(cm, axis=0))
best_predicted_class = np.argmax(cm.diagonal() / np.sum(cm, axis=1))

print(f"Prédiction préférée du modèle (classe la plus fréquemment prédite): {most_predicted_class}")
print(f"Classe la mieux prédite (plus haute précision): {best_predicted_class}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# Prédiction préférée du modèle (classe la plus fréquemment prédite): 7
# Classe la mieux prédite (plus haute précision): 7

# %% [markdown]
# ## Partie II. *Feedforward Neural Networks* à plusieurs couches
#
# Construisez et entraînez un réseau de neurones type Perceptron Multicouche (PMC) à $N_{H_l} = 3$ couches cachées et avec $m_1=32, m_2=16, m_3 = 16$ neurones respectivement pour les couches cachées 1, 2 et 3.
#
# * II.1) Combien de paramètres sont-ils optimisés au total ?
# * II.2) Quelle est la performance en apprentissage et validation ?
# * II.3) Montrez la matrice de confusion

# %%
#Ecrivez votre code ici
fnn = tf.keras.Sequential()
fnn.add(Flatten(input_shape=data_train[0].shape))
fnn.add(Dense(32, activation='relu'))
fnn.add(Dense(16, activation='relu'))
fnn.add(Dense(16, activation='relu'))
fnn.add(Dense(len(classes)))

fnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
fnn.fit(data_train, target_train, epochs=20, validation_data=(data_test, target_test))
print(fnn.summary())
# Out:
# C:\Users\Cs-Store\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.1997 - loss: 2.1248 - val_accuracy: 0.3029 - val_loss: 1.8794
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 980us/step - accuracy: 0.3209 - loss: 1.8596 - val_accuracy: 0.3494 - val_loss: 1.7982
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3467 - loss: 1.7937 - val_accuracy: 0.3607 - val_loss: 1.7660
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3580 - loss: 1.7727 - val_accuracy: 0.3654 - val_loss: 1.7383
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3668 - loss: 1.7456 - val_accuracy: 0.3763 - val_loss: 1.7229
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3705 - loss: 1.7323 - val_accuracy: 0.3682 - val_loss: 1.7303
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 985us/step - accuracy: 0.3757 - loss: 1.7259 - val_accuracy: 0.3821 - val_loss: 1.7043
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3741 - loss: 1.7197 - val_accuracy: 0.3696 - val_loss: 1.7408
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 967us/step - accuracy: 0.3817 - loss: 1.7093 - val_accuracy: 0.3851 - val_loss: 1.6893
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3816 - loss: 1.6985 - val_accuracy: 0.3701 - val_loss: 1.7278
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3824 - loss: 1.6958 - val_accuracy: 0.3733 - val_loss: 1.7066
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3887 - loss: 1.6886 - val_accuracy: 0.3793 - val_loss: 1.6910
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 991us/step - accuracy: 0.3860 - loss: 1.6833 - val_accuracy: 0.3841 - val_loss: 1.6957
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 978us/step - accuracy: 0.3865 - loss: 1.6797 - val_accuracy: 0.3776 - val_loss: 1.6977
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3858 - loss: 1.6779 - val_accuracy: 0.3838 - val_loss: 1.6844
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3909 - loss: 1.6783 - val_accuracy: 0.3854 - val_loss: 1.6835
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3903 - loss: 1.6684 - val_accuracy: 0.3881 - val_loss: 1.6826
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 978us/step - accuracy: 0.3918 - loss: 1.6693 - val_accuracy: 0.3883 - val_loss: 1.6746
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3928 - loss: 1.6748 - val_accuracy: 0.3705 - val_loss: 1.7071
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3941 - loss: 1.6681 - val_accuracy: 0.3875 - val_loss: 1.6667
# Model: "sequential_129"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_129 (Flatten)                │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_260 (Dense)                    │ (None, 32)                  │          98,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_261 (Dense)                    │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_262 (Dense)                    │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_263 (Dense)                    │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 297,920 (1.14 MB)
#  Trainable params: 99,306 (387.91 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 198,614 (775.84 KB)
# None

# %%
print('Training set accuracy:', fnn.evaluate(data_train, target_train)[1])
print('Testing set accuracy:', fnn.evaluate(data_test, target_test)[1])
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 566us/step - accuracy: 0.4040 - loss: 1.6319
# Training set accuracy: 0.40417999029159546
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.3961 - loss: 1.6547
# Testing set accuracy: 0.38749998807907104

# %%
history2 = fnn.fit(data_train, target_train, epochs=20, validation_data=(data_test, target_test))
# Afficher les précisions finales d'apprentissage et de validation
train_accuracy = history2.history['accuracy'][-1]
val_accuracy = history2.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {train_accuracy:.4f}")
print(f"Final Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3941 - loss: 1.6590 - val_accuracy: 0.3934 - val_loss: 1.6709
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3954 - loss: 1.6559 - val_accuracy: 0.3741 - val_loss: 1.6981
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4002 - loss: 1.6446 - val_accuracy: 0.3829 - val_loss: 1.6825
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 989us/step - accuracy: 0.4005 - loss: 1.6550 - val_accuracy: 0.3817 - val_loss: 1.6797
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 970us/step - accuracy: 0.3916 - loss: 1.6533 - val_accuracy: 0.3859 - val_loss: 1.6805
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 977us/step - accuracy: 0.3995 - loss: 1.6447 - val_accuracy: 0.3865 - val_loss: 1.6872
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 971us/step - accuracy: 0.4024 - loss: 1.6385 - val_accuracy: 0.3953 - val_loss: 1.6596
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 992us/step - accuracy: 0.3987 - loss: 1.6466 - val_accuracy: 0.3667 - val_loss: 1.7130
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 967us/step - accuracy: 0.4080 - loss: 1.6300 - val_accuracy: 0.3792 - val_loss: 1.6843
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 984us/step - accuracy: 0.4046 - loss: 1.6343 - val_accuracy: 0.3860 - val_loss: 1.6846
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4038 - loss: 1.6331 - val_accuracy: 0.3916 - val_loss: 1.6650
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4012 - loss: 1.6353 - val_accuracy: 0.3864 - val_loss: 1.6772
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4053 - loss: 1.6287 - val_accuracy: 0.3986 - val_loss: 1.6500
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4046 - loss: 1.6318 - val_accuracy: 0.3996 - val_loss: 1.6550
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 991us/step - accuracy: 0.4063 - loss: 1.6253 - val_accuracy: 0.3822 - val_loss: 1.6920
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 984us/step - accuracy: 0.4077 - loss: 1.6208 - val_accuracy: 0.3900 - val_loss: 1.6775
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4014 - loss: 1.6327 - val_accuracy: 0.3949 - val_loss: 1.6669
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4060 - loss: 1.6274 - val_accuracy: 0.3945 - val_loss: 1.6581
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 994us/step - accuracy: 0.4055 - loss: 1.6179 - val_accuracy: 0.3921 - val_loss: 1.6661
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 991us/step - accuracy: 0.4097 - loss: 1.6163 - val_accuracy: 0.3853 - val_loss: 1.6743
# Final Training Accuracy: 0.4066
# Final Validation Accuracy: 0.3853

# %%
prediction_list = fnn.predict(data_test)
prediction = [np.argmax(prob_list) for prob_list in prediction_list]
print('Confusion matrix on test set:', tf.math.confusion_matrix(target_test.flatten(), prediction))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# Confusion matrix on test set: tf.Tensor(
# [[504  37  48  27  28  28  23  47 186  72]
#  [ 41 460  20  19  25  24  39  24 115 233]
#  [128  48 155  44 209 104 165  91  31  25]
#  [ 53  62  79 148  66 265 185  60  31  51]
#  [ 69  26 114  51 342  68 180  95  32  23]
#  [ 28  26  63 109  83 354 149  86  62  40]
#  [ 12  51  55  88 127 102 494  43   7  21]
#  [ 58  23  79  31 122  89  50 437  32  79]
#  [174 141  16  23   8  47   8  17 491  75]
#  [ 51 215  11  31  11  22  30  45  94 490]], shape=(10, 10), dtype=int32)

# %% [markdown]
# ## Partie III. Réseaux de neurones convolutionnels (*CNN*)
#
#
# Créez un CNN à l'image de *LeNet-5* (LeCun et al., 1998), qui consiste en une double alternance entre une couche convolutionnelle ($m=32$, kernel de $5x5$) et une couche de *Maximum Pooling* (kernel de $2x2$), suivie d'une couche dense ($m=64$).

# %%
#Ecrivez votre code ici
cnn = tf.keras.Sequential()
cnn.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
cnn.add(MaxPooling2D((2, 2)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling2D((2, 2)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(64,activation='softmax'))
cnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
cnn.fit(data_train, target_train, epochs=20, validation_data=(data_test, target_test))
print(cnn.summary())
# Out:
# C:\Users\Cs-Store\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/20
# C:\Users\Cs-Store\AppData\Roaming\Python\Python39\site-packages\keras\src\backend\tensorflow\nn.py:625: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.3286 - loss: 1.8701 - val_accuracy: 0.5401 - val_loss: 1.2761
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.5665 - loss: 1.2292 - val_accuracy: 0.5971 - val_loss: 1.1218
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.6419 - loss: 1.0303 - val_accuracy: 0.6520 - val_loss: 0.9956
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.6770 - loss: 0.9322 - val_accuracy: 0.6694 - val_loss: 0.9403
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7010 - loss: 0.8705 - val_accuracy: 0.6820 - val_loss: 0.9026
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7248 - loss: 0.8008 - val_accuracy: 0.6858 - val_loss: 0.8867
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7354 - loss: 0.7543 - val_accuracy: 0.7067 - val_loss: 0.8480
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7530 - loss: 0.7123 - val_accuracy: 0.7041 - val_loss: 0.8579
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7650 - loss: 0.6758 - val_accuracy: 0.7141 - val_loss: 0.8310
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7761 - loss: 0.6407 - val_accuracy: 0.7093 - val_loss: 0.8426
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7860 - loss: 0.6084 - val_accuracy: 0.7008 - val_loss: 0.8887
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7981 - loss: 0.5811 - val_accuracy: 0.7122 - val_loss: 0.8613
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8057 - loss: 0.5556 - val_accuracy: 0.7152 - val_loss: 0.8615
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8138 - loss: 0.5370 - val_accuracy: 0.7127 - val_loss: 0.8735
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8195 - loss: 0.5136 - val_accuracy: 0.7079 - val_loss: 0.9015
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8256 - loss: 0.4931 - val_accuracy: 0.7099 - val_loss: 0.8986
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8349 - loss: 0.4687 - val_accuracy: 0.7062 - val_loss: 0.9410
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8444 - loss: 0.4422 - val_accuracy: 0.6992 - val_loss: 0.9730
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8453 - loss: 0.4318 - val_accuracy: 0.7077 - val_loss: 0.9608
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8570 - loss: 0.4120 - val_accuracy: 0.7114 - val_loss: 0.9969
# Model: "sequential_130"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 4, 4, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_130 (Flatten)                │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_264 (Dense)                    │ (None, 64)                  │          65,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 365,762 (1.40 MB)
#  Trainable params: 121,920 (476.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 243,842 (952.51 KB)
# None

# %% [markdown]
# * III.1) Combien de paramètres arrivent-ils en entrée de la couche dense ?
#
# ***Réponse:***
# first layer Conv2D = $30 \times 30 \times 32$ \
# first layer Maxpooling2D = $15 \times 15 \times 32$ \
# Second layer Conv2D = $13 \times 13 \times 64$ \
# Second layer Maxpooling2D = $6 \times 6 \times 64$ \
# Third layer Conv2D = $4 \times 4 \times 64 = 1024$
# * III.2) Combien de paramètres sont-ils entraînés au total ?
#
# ***Réponse:*** 121,920
# * III.3) Quelle est la performance d'apprentissage et de validation ?

# %%
#Ecrivez votre code ici
history = cnn.fit(data_train, target_train, epochs=20, validation_data=(data_test, target_test))

# Afficher les précisions finales d'apprentissage et de validation
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {train_accuracy:.4f}")
print(f"Final Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9365 - loss: 0.1737 - val_accuracy: 0.6798 - val_loss: 1.8275
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9385 - loss: 0.1706 - val_accuracy: 0.6843 - val_loss: 1.8143
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9381 - loss: 0.1699 - val_accuracy: 0.6689 - val_loss: 2.0056
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9412 - loss: 0.1639 - val_accuracy: 0.6796 - val_loss: 1.9458
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9434 - loss: 0.1561 - val_accuracy: 0.6796 - val_loss: 2.0045
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9416 - loss: 0.1568 - val_accuracy: 0.6856 - val_loss: 2.0035
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9443 - loss: 0.1524 - val_accuracy: 0.6754 - val_loss: 2.1282
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9443 - loss: 0.1542 - val_accuracy: 0.6831 - val_loss: 2.1697
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9461 - loss: 0.1501 - val_accuracy: 0.6819 - val_loss: 2.1879
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9457 - loss: 0.1448 - val_accuracy: 0.6827 - val_loss: 2.2334
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9499 - loss: 0.1358 - val_accuracy: 0.6763 - val_loss: 2.3022
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9512 - loss: 0.1364 - val_accuracy: 0.6772 - val_loss: 2.3343
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9492 - loss: 0.1385 - val_accuracy: 0.6780 - val_loss: 2.3252
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9570 - loss: 0.1193 - val_accuracy: 0.6777 - val_loss: 2.4950
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9506 - loss: 0.1344 - val_accuracy: 0.6734 - val_loss: 2.5093
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9555 - loss: 0.1220 - val_accuracy: 0.6735 - val_loss: 2.4596
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9524 - loss: 0.1318 - val_accuracy: 0.6735 - val_loss: 2.5197
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9553 - loss: 0.1238 - val_accuracy: 0.6737 - val_loss: 2.5960
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9552 - loss: 0.1211 - val_accuracy: 0.6781 - val_loss: 2.6175
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9599 - loss: 0.1103 - val_accuracy: 0.6755 - val_loss: 2.6117
# Final Training Accuracy: 0.9516
# Final Validation Accuracy: 0.6755

# %% [markdown]
# ## Partie IV. Transfer learning
#
# Avec l'immense progression récente du Deep Learning, il est souvent plus intéressant de créer un modèle à partir d'un autre modèle déjà entraîné et l'ajuster (*fine-tune*) selon la tâche spécifique que l'on veut réaliser. Actuellement un large catalogue de modèles très complexes entraînés sur des bases de données de très grande taille est à disposition du public général.
#
# Commençons par créer un réseau type *ResNet-18* (He et al., 2015) pré-entraîné sur la base de données *ImageNet*

# %%
#import torch 
from tensorflow.keras.applications import ResNet50

#resnet = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=True) 

ResNet50_model = ResNet50(
    include_top=False, 
    weights='imagenet', 
    input_shape= (32, 32, 3),
    pooling='avg')

tl_cnn = Sequential()
tl_cnn.add(ResNet50_model)
tl_cnn.add(Flatten())
tl_cnn.add(Dense(10, activation='softmax'))
tl_cnn.summary()

# %% [markdown]
# Maintenant on ajuste le modèle pré-entraîné à notre problème spécifique (*fine-tuning*)
# (Il est préférable d'utiliser un GPU. Par exemple, Google Colab, Codesphere, Gradient by Paperspace, Kaggle, proposent des GPU gratuitement)

# %%
tl_cnn.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
history4 = tl_cnn.fit(data_train, target_train, epochs=20, validation_data=(data_test, target_test))

# %% [markdown]
# Remplissez le tableau ci-dessous selon les différentes méthodes de classification testées.
#
# | Classifieur        | Perf Apprentissage | Perf Test |
# |--------------------|--------------------|-----------|
# | *FNN* simple       |  |  |
# | *FNN* profond      |  |  |
# | *CNN*              |  |  |
# | *ResNet50*         |  |  |
#
# * IV.1) Quel est le meilleur classifieur ? Justifiez

# %% [markdown]
# IV.2) Pendant quelques années les modèles ResNet ont été le *silver standard* dans la classification d'images. Plus récemment, une autre famille de modèles appelée *ConvNet* (Liu et al., 2022) a montré des meilleures performances. Refaite l'expérience précédente en partant d'un modèle *ConvNet* pré-entraîné.
# (Il est préférable d'utiliser un GPU. Par exemple, Google Colab, Codesphere, Gradient by Paperspace, Kaggle, proposent des GPU gratuitement)

# %%
#Ecrivez votre code ici
